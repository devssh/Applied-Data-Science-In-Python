# %% [markdown]
# # Assignment 4
#
# Before working on this assignment please read these instructions fully. In the submission area, you will notice that you can click the link to **Preview the Grading** for each step of the assignment. This is the criteria that will be used for peer grading. Please familiarize yourself with the criteria before beginning the assignment.
#
# This assignment requires that you to find **at least** two datasets on the web which are related, and that you visualize these datasets to answer a question with the broad topic of **religious events or traditions** (see below) for the region of **Ann Arbor, Michigan, United States**, or **United States** more broadly.
#
# You can merge these datasets with data from different regions if you like! For instance, you might want to compare **Ann Arbor, Michigan, United States** to Ann Arbor, USA. In that case at least one source file must be about **Ann Arbor, Michigan, United States**.
#
# You are welcome to choose datasets at your discretion, but keep in mind **they will be shared with your peers**, so choose appropriate datasets. Sensitive, confidential, illicit, and proprietary materials are not good choices for datasets for this assignment. You are welcome to upload datasets of your own as well, and link to them using a third party repository such as github, bitbucket, pastebin, etc. Please be aware of the Coursera terms of service with respect to intellectual property.
#
# Also, you are welcome to preserve data in its original language, but for the purposes of grading you should provide english translations. You are welcome to provide multiple visuals in different languages if you would like!
#
# As this assignment is for the whole course, you must incorporate principles discussed in the first week, such as having as high data-ink ratio (Tufte) and aligning with Cairo’s principles of truth, beauty, function, and insight.
#
# Here are the assignment instructions:
#
#  * State the region and the domain category that your data sets are about (e.g., **Ann Arbor, Michigan, United States** and **religious events or traditions**).
#  * You must state a question about the domain category and region that you identified as being interesting.
#  * You must provide at least two links to available datasets. These could be links to files such as CSV or Excel files, or links to websites which might have data in tabular form, such as Wikipedia pages.
#  * You must upload an image which addresses the research question you stated. In addition to addressing the question, this visual should follow Cairo's principles of truthfulness, functionality, beauty, and insightfulness.
#  * You must contribute a short (1-2 paragraph) written justification of how your visualization addresses your stated research question.
#
# What do we mean by **religious events or traditions**?  For this category you might consider calendar events, demographic data about religion in the region and neighboring regions, participation in religious events, or how religious events relate to political events, social movements, or historical events.
#
# ## Tips
# * Wikipedia is an excellent source of data, and I strongly encourage you to explore it for new data sources.
# * Many governments run open data initiatives at the city, region, and country levels, and these are wonderful resources for localized data sources.
# * Several international agencies, such as the [United Nations](http://data.un.org/), the [World Bank](http://data.worldbank.org/), the [Global Open Data Index](http://index.okfn.org/place/) are other great places to look for data.
# * This assignment requires you to convert and clean datafiles. Check out the discussion forums for tips on how to do this from various sources, and share your successes with your fellow students!
#
# ## Example
# Looking for an example? Here's what our course assistant put together for the **Ann Arbor, MI, USA** area using **sports and athletics** as the topic. [Example Solution File](./readonly/Assignment4_example.pdf)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns
plt.style.use("seaborn-colorblind")

# %%
df = pd.read_excel("BaylorReligionSurveyWaveII(2007).XLSX").fillna(0)
df["DENOM"][df["DENOM"]==0]="ATHEIST"
df["DENOM"]=df["DENOM"].apply(lambda val: "CATHOLIC" if "CATHOLIC" in val else val)
df["DENOM"]=df["DENOM"].apply(lambda val: "PROTESTANT" if "PROTESTANT" in val or "PENTE" in val or
                              "WESL" in val else val)
df["DENOM"]=df["DENOM"].apply(lambda val: "REFORMED" if "REFOR" in val else val)
df["DENOM"]=df["DENOM"].apply(lambda val: "BAPTIST" if "BAPTI" in val or "CBF" in val else val)
df["DENOM"]=df["DENOM"].apply(lambda val: "METHODIST" if "METHODIST" in val else val)
df["DENOM"]=df["DENOM"].apply(lambda val: "LUTHERAN" if "LUTHER" in val or "ELCA" in val or
                              "MISSOU" in val or "LCMS" in val else val)
df["DENOM"]=df["DENOM"].apply(lambda val: "PRESBYTARIAN" if "PRESBYT" in val or "PCUSA" in val else val)
df["DENOM"]=df["DENOM"].apply(lambda val: "ADVENTIST" if "ADVENT" in val or "SOUTHERN" in val else val)
df["DENOM"]=df["DENOM"].apply(lambda val: "APOSTOLIC" if "APOSTO" in val else val)
df["DENOM"]=df["DENOM"].apply(lambda val: "EVANGELICAL" if "EVANG" in val else val)
df["DENOM"]=df["DENOM"].apply(lambda val: "ISLAM" if "SUNNI" in val else val)
df["DENOM"]=df["DENOM"].apply(lambda val: "BUDDHIST" if "NICHIREN" in val else val)
df["DENOM"]=df["DENOM"].apply(lambda val: "GURU" if "GURU" in val else val)
df["DENOM"]=df["DENOM"].apply(lambda val: "JEWISH" if "JEWISH" in val or "JUDA" in val or
                              "JEHOV" in val or "EMMAN" in val else val)
df["DENOM"]=df["DENOM"].apply(lambda val: "FELLOWSHIP" if "FELLOW" in val or "CONGR" in val or 
                              "ASSOC" in val or "FRIEND" in val else val)
df["DENOM"]=df["DENOM"].apply(lambda val: "PAGAN" if "PAGAN" in val or "INDEP" in val or
                              "WICCA" in val or "IDENT" in val else val)
df["DENOM"]=df["DENOM"].apply(lambda val: "UNITARIAN" if "UNITED" in val or "UNIT" in val else val)
df["DENOM"]=df["DENOM"].apply(lambda val: "CONSERVATIVE" if "CONSER" in val or "ORTHO" in val else val)
df["DENOM"]=df["DENOM"].apply(lambda val: "CHRISTIAN" if "ASSEMBL" in val or "CHURCH" in val or 
                              "WORD" in val or "FAITH" in val or val.startswith("ST ") or "CHRIS" in val or
                              "BIBL" in val or "SAINT" in val or "CHAPEL" in val or 
                              "BELIEV" in val or "BORN" in val or "CALV" in val or "GOSPEL" in val or
                              "VINEY" in val or "ANGLICAN" in val or "EPIS" in val or "HOLI" in val or
                              "COVEN" in val or "NAZERENE" in val or "NAZARENE" in val or "ECLECTIC" in val or 
                              "LCA" in val or "INTER" in val or "LDS" in val or "QUAKE" in val or 
                              "GENER" in val or "MORM" in val or "MORI" in val or "OBC" in val else val)
df["DENOM"]=df["DENOM"].apply(lambda val: "AGNOSTIC/ANONYMOUS" if "NON" in val or "GNOSTIC" in val or
                              "ATHEIST" in val or "HORDE" in val else val)
df=df.groupby("DENOM").apply(sum)
df["DENOM"] = df.index

df
# Out:
# /Users/devashishsood/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#                                ID    WEIGHT  REGION   RELIG1  RELIG2  \
# DENOM
# ADVENTIST             78566124706    7.3476      26    208.0     0.0
# AGNOSTIC/ANONYMOUS  6440690989207  733.9569    1860  22239.0   644.0
# APOSTOLIC             29049772600    1.6729       8     46.0     0.0
# BAPTIST             1578044785070  194.1987     477   2215.0    12.0
# BUDDHIST               9683137900    2.8614       4     15.0     0.0
# CHRISTIAN           3719614185863  396.0928    1017   8220.0   131.0
# CONSERVATIVE         126234661200    9.6304      30    439.0     0.0
# EVANGELICAL          116198778000   14.6071      21    290.0   235.0
# ...

# %%
df1 = pd.read_excel("BaylorReligionSurveyWaveI(2005).XLSX").fillna(0)
df1.rename(columns={"WGT":"WEIGHT","Q2":"DENOM"},inplace=True)
df1["DENOM"][df1["DENOM"]==0]="ATHEIST"
df1["DENOM"]=df1["DENOM"].str.upper()
df1["DENOM"]=df1["DENOM"].apply(lambda val: "CATHOLIC" if "CATHOLIC" in val else val)
df1["DENOM"]=df1["DENOM"].apply(lambda val: "PROTESTANT" if "PROTESTANT" in val or "PENTE" in val or
                              "WESL" in val else val)
df1["DENOM"]=df1["DENOM"].apply(lambda val: "REFORMED" if "REFOR" in val else val)
df1["DENOM"]=df1["DENOM"].apply(lambda val: "BAPTIST" if "BAPTI" in val or "CBF" in val else val)
df1["DENOM"]=df1["DENOM"].apply(lambda val: "METHODIST" if "METHODIST" in val else val)
df1["DENOM"]=df1["DENOM"].apply(lambda val: "LUTHERAN" if "LUTHER" in val or "ELCA" in val or
                              "MISSOU" in val or "LCMS" in val else val)
df1["DENOM"]=df1["DENOM"].apply(lambda val: "PRESBYTARIAN" if "PRESBYT" in val or "PCUSA" in val else val)
df1["DENOM"]=df1["DENOM"].apply(lambda val: "ADVENTIST" if "ADVENT" in val or "SOUTHERN" in val else val)
df1["DENOM"]=df1["DENOM"].apply(lambda val: "APOSTOLIC" if "APOSTO" in val else val)
df1["DENOM"]=df1["DENOM"].apply(lambda val: "EVANGELICAL" if "EVANG" in val else val)
df1["DENOM"]=df1["DENOM"].apply(lambda val: "ISLAM" if "SUNNI" in val else val)
df1["DENOM"]=df1["DENOM"].apply(lambda val: "BUDDHIST" if "NICHIREN" in val else val)
df1["DENOM"]=df1["DENOM"].apply(lambda val: "GURU" if "GURU" in val else val)
df1["DENOM"]=df1["DENOM"].apply(lambda val: "JEWISH" if "JEWISH" in val or "JUDA" in val or
                              "JEHOV" in val or "EMMAN" in val else val)
df1["DENOM"]=df1["DENOM"].apply(lambda val: "FELLOWSHIP" if "FELLOW" in val or "CONGR" in val or 
                              "ASSOC" in val or "FRIEND" in val else val)
df1["DENOM"]=df1["DENOM"].apply(lambda val: "PAGAN" if "PAGAN" in val or "INDEP" in val or
                              "WICCA" in val or "IDENT" in val else val)
df1["DENOM"]=df1["DENOM"].apply(lambda val: "UNITARIAN" if "UNITED" in val or "UNIT" in val else val)
df1["DENOM"]=df1["DENOM"].apply(lambda val: "CONSERVATIVE" if "CONSER" in val or "ORTHO" in val else val)
df1["DENOM"]=df1["DENOM"].apply(lambda val: "CHRISTIAN" if "ASSEMBL" in val or "CHURCH" in val or 
                              "WORD" in val or "FAITH" in val or val.startswith("ST ") or "CHRIS" in val or
                              "BIBL" in val or "SAINT" in val or "CHAPEL" in val or 
                              "BELIEV" in val or "BORN" in val or "CALV" in val or "GOSPEL" in val or
                              "VINEY" in val or "ANGLICAN" in val or "EPIS" in val or "HOLI" in val or
                              "COVEN" in val or "NAZERENE" in val or "NAZARENE" in val or "ECLECTIC" in val or 
                              "LCA" in val or "INTER" in val or "LDS" in val or "QUAKE" in val or 
                              "GENER" in val or "MORM" in val or "MORI" in val or "OBC" in val else val)
df1["DENOM"]=df1["DENOM"].apply(lambda val: "AGNOSTIC/ATHEIST" if "NON" in val or "GNOSTIC" in val or
                              "ATHEIST" in val or "HORDE" in val else val)

df1=df1.groupby("DENOM").apply(sum)
df1["DENOM"] = df1.index
df1
# Out:
# /Users/devashishsood/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
#                                               ID  WEIGHT  REGION       Q1  \
# DENOM
# ADVENTIST                               49034214    3.92      12     52.0
# AGNOSTIC/ATHEIST                     11427819741  823.25    2078  21479.0
# ALCU                                    12259093    0.51       2     26.0
# AME 1                                   12258162    1.00       1     28.0
# AMERICAN                                12259294    1.03       3      6.0
# APOSTOLIC                               44201155    1.48       3     63.0
# BAPTIST                               2544464519  205.20     482   1109.0
# ...

# %%
arr=[*df.columns]
arr
# Out:
# ['ID',
#  'WEIGHT',
#  'REGION',
#  'RELIG1',
#  'RELIG2',
#  'DENOM',
#  'RELGIOUS',
#  'ATTEND',
#  'HOWLONG',
#  'HOWMANY',
#  'PERCWHT',
#  'PERCHISP',
#  'PERCBLK',
#  'PERCASN',
#  'ATTENDO',
#  'TITHE',
#  'HHCONTRB',
#  'PORN',
#  'GAMBLING',
#  'REVEAL',
#  'PREMARSX',
#  'COHABIT',
#  'CONTRA',
#  'ABORTION',
#  'HOMOSEX',
#  'DISPWLTH',
#  'FRNDWSHP',
#  'FRNDDIFF',
#  'FRNDDONT',
#  'RELIGED',
#  'CHOIR',
#  'COUNSEL',
#  'SOCIAL',
#  'WTNSSFR',
#  'WTNSSST',
#  'COMMPRAY',
#  'COMMBIBL',
#  'FBPROGRM',
#  'OTHERREL',
#  'BIBLEBEL',
#  'BORNAGN',
#  'CHARISMA',
#  'CONTMPLT',
#  'EVANGEL',
#  'FUNDAMEN',
#  'MAINLINE',
#  'MYSTIC',
#  'PENTECST',
#  'RELLEFT',
#  'RELRIGHT',
#  'SEEKER',
#  'SPIRIT',
#  'THEOCON',
#  'THEOLIB',
#  'TRADIT',
#  'SACREDBK',
#  'PRAY',
#  'BIBLE',
#  'GOD',
#  'GODFORCE',
#  'GODREMOV',
#  'GODWORLD',
#  'GODPERS',
#  'GODANGER',
#  'GODMYSIN',
#  'GODINVLV',
#  'GODMYAFF',
#  'GODMALE',
#  'GODABSOL',
#  'GODCRIT',
#  'GODDIST',
# ...

# %%
df["PORN"]
# Out:
# DENOM
# ADVENTIST              13.0
# AGNOSTIC/ANONYMOUS    798.0
# APOSTOLIC               3.0
# BAPTIST               243.0
# BUDDHIST                5.0
# CHRISTIAN             537.0
# CONSERVATIVE           13.0
# EVANGELICAL            16.0
# FELLOWSHIP             32.0
# GURU                    1.0
# ISLAM                   1.0
# JEWISH                 15.0
# LUTHERAN              159.0
# METHODIST             157.0
# NATIVE AMERICAN         1.0
# PAGAN                   9.0
# PRESBYTARIAN           61.0
# PROTESTANT             30.0
# REFORMED               42.0
# UNITARIAN              37.0
# Name: PORN, dtype: float64

# %%
[*df["DENOM"].unique()]
# Out:
# ['ADVENTIST',
#  'AGNOSTIC/ANONYMOUS',
#  'APOSTOLIC',
#  'BAPTIST',
#  'BUDDHIST',
#  'CHRISTIAN',
#  'CONSERVATIVE',
#  'EVANGELICAL',
#  'FELLOWSHIP',
#  'GURU',
#  'ISLAM',
#  'JEWISH',
#  'LUTHERAN',
#  'METHODIST',
#  'NATIVE AMERICAN',
#  'PAGAN',
#  'PRESBYTARIAN',
#  'PROTESTANT',
#  'REFORMED',
#  'UNITARIAN']

# %%
dfx = df.iloc[[1,3,5,12,13,16,17,18,19]]
dfx = dfx[["WEIGHT","PORN","PREMARSX","HOMOSEX","MARIJUAN","ABORTION","UNDER18","CHILDREN"]]
dfy=dfx["WEIGHT"].copy()
xpos = range(len(dfx.index))
xpos = [pos*7 + 3 for pos in xpos]
xpos1 = [pos-3 for pos in xpos]
xpos2 = [pos-2 for pos in xpos]
xpos3 = [pos-1 for pos in xpos]
xpos4 = [pos for pos in xpos]
xpos5 = [pos+1 for pos in xpos]
xpos6 = [pos+2 for pos in xpos]
xpos7 = [pos+3 for pos in xpos]

gspec = gridspec.GridSpec(3, 1)

plt.figure(figsize=(20,10),dpi=500)
top_histogram = plt.subplot(gspec[0, 1:])
bottom_histogram = plt.subplot(gspec[1:, 1:], sharex=top_histogram)

top_histogram.set_xticks(xpos)
top_histogram.set_xticklabels(dfx.index)

dfx=dfx.apply(lambda num: num/dfx["WEIGHT"])
top_histogram.bar(xpos1,dfx["PORN"], label="Watch Porn", color="black")
top_histogram.bar(xpos2,dfx["PREMARSX"], label="Accept pre-marital sex")
top_histogram.bar(xpos3,dfx["HOMOSEX"], label="Accept Homosexuality")
top_histogram.bar(xpos4,dfx["MARIJUAN"], label="Smoke Marijuana")
top_histogram.bar(xpos5,dfx["ABORTION"], label="Pro Abortion")
top_histogram.bar(xpos6,dfx["UNDER18"], label="Are under 18")
top_histogram.bar(xpos7,dfx["CHILDREN"], label="Have children")

top_histogram.legend(loc="upper left")
top_histogram.set_ylabel("Ratings/ Approvals")
#top_histogram.set_xlabel("Religious Belief")

bottom_histogram.bar(xpos, dfy, width=5)
bottom_histogram.invert_yaxis()
bottom_histogram.get_xaxis().set_visible(False)
bottom_histogram.set_yticks([])
bottom_histogram.set_ylabel("Relative weight in no. of people")

for i,pos in enumerate(xpos):
    bottom_histogram.text(pos-2, dfy.iloc[i]+50, dfy.iloc[i])

#plt.savefig("Religion and Beliefs.svg", type="svg")   
plt.show()
